# %%
# !pip install textblob
# Out:
# Collecting textblob
#   Downloading textblob-0.20.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: nltk>=3.9 in .\anaconda3\Lib\site-packages (from textblob) (3.10.0)
# Requirement already satisfied: defusedxml in .\anaconda3\Lib\site-packages (from nltk>=3.9->textblob) (0.7.1)
# Requirement already satisfied: click in .\anaconda3\Lib\site-packages (from nltk>=3.9->textblob) (8.4.1)
# Requirement already satisfied: joblib in .\anaconda3\Lib\site-packages (from nltk>=3.9->textblob) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in .\anaconda3\Lib\site-packages (from nltk>=3.9->textblob) (2026.5.9)
# Requirement already satisfied: tqdm in .\anaconda3\Lib\site-packages (from nltk>=3.9->textblob) (4.68.2)
# Requirement already satisfied: colorama in .\anaconda3\Lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# Downloading textblob-0.20.1-py3-none-any.whl (624 kB)
#    ---------------------------------------- 0.0/625.0 kB ? eta -:--:--
#    --------------------------------- ------ 524.3/625.0 kB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 625.0/625.0 kB 3.4 MB/s  0:00:00
# Installing collected packages: textblob
# Successfully installed textblob-0.20.1

# %%
from textblob import TextBlob


def analyze_sentiment():
  print("--- Real-Time Sentiment Analyzer ---")
  print("Type any sentence to analyz. Type 'exit' to quit.\n")

  while True:
    user_input = input("Enter Text: ")

    if user_input.lower().strip() == "exit":
      print("Exiting Analyzer.")
      break

    if not user_input.strip():
      continue

    # Process text using TextBlob
    blob = TextBlob(user_input)
    polarity = blob.sentiment.polarity  # Range: -1.0 (Negative) to +1.0 (Positive)
    subjectivity = (
        blob.sentiment.subjectivity
    )  # Range: 0.0 (Factual) to 1.0 (Opinion)

    # Interpret results
    if polarity > 0.1:
      sentiment_label = "POSITIVE 🙂"
    elif polarity < -0.1:
      sentiment_label = "NEGATIVE 🙁"
    else:
      sentiment_label = "NEUTRAL 😐"

    print(f" -> Sentiment: {sentiment_label}")
    print(
        f" -> Score: Polarity={polarity:.2f}, Subjectivity={subjectivity:.2f}\n"
    )


if __name__ == "__main__":
  analyze_sentiment()
# Out:
# --- Real-Time Sentiment Analyzer ---
# Type any sentence to analyz. Type 'exit' to quit.
# Enter Text:  hi, im enjoying working with jupyter notebook
#  -> Sentiment: POSITIVE 🙂
#  -> Score: Polarity=0.50, Subjectivity=0.60
# Enter Text:  exit
# Exiting Analyzer.
