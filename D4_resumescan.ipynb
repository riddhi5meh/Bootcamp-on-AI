# %%
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in .\anaconda3\Lib\site-packages (3.8.16)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in .\anaconda3\Lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in .\anaconda3\Lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in .\anaconda3\Lib\site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in .\anaconda3\Lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in .\anaconda3\Lib\site-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in .\anaconda3\Lib\site-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in .\anaconda3\Lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in .\anaconda3\Lib\site-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in .\anaconda3\Lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in .\anaconda3\Lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in .\anaconda3\Lib\site-packages (from spacy) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in .\anaconda3\Lib\site-packages (from spacy) (0.25.1)
# Requirement already satisfied: click<9.0.0,>=8.2.1 in .\anaconda3\Lib\site-packages (from spacy) (8.4.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in .\anaconda3\Lib\site-packages (from spacy) (4.68.2)
# Requirement already satisfied: numpy>=1.19.0 in .\anaconda3\Lib\site-packages (from spacy) (2.4.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in .\anaconda3\Lib\site-packages (from spacy) (2.34.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in .\anaconda3\Lib\site-packages (from spacy) (2.13.4)
# Requirement already satisfied: jinja2 in .\anaconda3\Lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in .\anaconda3\Lib\site-packages (from spacy) (83.0.0)
# Requirement already satisfied: packaging>=20.0 in .\anaconda3\Lib\site-packages (from spacy) (26.0)
# Requirement already satisfied: colorama in .\anaconda3\Lib\site-packages (from click<9.0.0,>=8.2.1->spacy) (0.4.6)
# Requirement already satisfied: annotated-types>=0.6.0 in .\anaconda3\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in .\anaconda3\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in .\anaconda3\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\anaconda3\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\anaconda3\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in .\anaconda3\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in .\anaconda3\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in .\anaconda3\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.6.17)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in .\anaconda3\Lib\site-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in .\anaconda3\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in .\anaconda3\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in .\anaconda3\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in .\anaconda3\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.25.0)
# Requirement already satisfied: smart-open>=5.2.1 in .\anaconda3\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (8.0.1)
# Requirement already satisfied: httpx>=0.24.0 in .\anaconda3\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: anyio in .\anaconda3\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.12.1)
# Requirement already satisfied: httpcore==1.* in .\anaconda3\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in .\anaconda3\Lib\site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in .\anaconda3\Lib\site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in .\anaconda3\Lib\site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in .\anaconda3\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: wrapt in .\anaconda3\Lib\site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in .\anaconda3\Lib\site-packages (from jinja2->spacy) (3.0.3)

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Using cached en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy

# Load spaCy's lightweight English core model (~12MB)
nlp = spacy.load("en_core_web_sm")

# Sample unstructured text input
raw_resume_text = """
Rahul Sharma is a Software Developer living in New Delhi. 
He worked at Google for 3 years starting from March 2021. 
Rahul graduated from Delhi University and has expertise in Python, Machine Learning and AWS.
"""

print("Processing text with spaCy...\n")
doc = nlp(raw_resume_text)

print("--- Extracted Named Entities ---")
# Extract entities like Persons, Organizations, Locations, and Dates
for ent in doc.ents:
  print(f"Entity: {ent.text:<20} | Type: {ent.label_:<10} ({spacy.explain(ent.label_)})")

print("\n--- Identified Keywords/Nouns ---")
# Extract key nouns/skills
nouns = [token.text for token in doc if token.pos_ in ["NOUN", "PROPN"]]
print("Key Nouns Found:", list(set(nouns)))
# Out:
# Processing text with spaCy...
#
# --- Extracted Named Entities ---
# Entity: Rahul Sharma         | Type: PERSON     (People, including fictional)
# Entity: Software             | Type: ORG        (Companies, agencies, institutions, etc.)
# Entity: New Delhi            | Type: GPE        (Countries, cities, states)
# Entity: Google               | Type: ORG        (Companies, agencies, institutions, etc.)
# Entity: 3 years              | Type: DATE       (Absolute or relative dates or periods)
# Entity: March 2021           | Type: DATE       (Absolute or relative dates or periods)
# Entity: Delhi University     | Type: ORG        (Companies, agencies, institutions, etc.)
# Entity: Python               | Type: ORG        (Companies, agencies, institutions, etc.)
# Entity: Machine Learning     | Type: PERSON     (People, including fictional)
#
# --- Identified Keywords/Nouns ---
# Key Nouns Found: ['Sharma', 'AWS', 'Google', 'University', 'Software', 'Machine', 'Developer', 'expertise', 'Rahul', 'March', 'Learning', 'Delhi', 'New', 'Python', 'years']
